# %% [markdown]
# The following description was researched on Gemini 3/8/2026. Gradient descent is one of the most important calculations for machine learning. Below is a simplified example which is written in a lengthier format to provide a clearer trail of how you get from the beginning of the calculation to the end. In this example, the output the calculation is trying to create is 10.
# The smaller the mean squared error, the closer the vector is to getting to the output.
# Think of the slope of the vector like walking downhill.
# As the slope falls, the vector gets toward the true output, which is at the bottom of the slope.
# If the increments as illustrated below—whereby each row represents an incremental drop in the slope—drop too slowly, the problem may not get to the bottom of the slope.
# However, if the incremental drops are too large, the increment will surpass the drop and miss the descent.  The below code was produced by Gemini on 3/8/2026

# %%
# Your data
x_data = 5
y_true = 10

# Initial "guesses"
w = 0.0
b = 0.0
learning_rate = 0.01

print(f"{'Iteration':<10} | {'Weight (w)':<10} | {'Bias (b)':<10} | {'Prediction':<10}")
print("-" * 50)

for i in range(10):
    w, b = gradient_descent(x_data, y_true, w, b, learning_rate)
    y_pred = w * x_data + b
    print(f"{i+1:<10} | {w:<10.4f} | {b:<10.4f} | {y_pred:<10.4f}")
# Out:
# Iteration  | Weight (w) | Bias (b)   | Prediction
# --------------------------------------------------
# 1          | 1.0000     | 0.2000     | 5.2000
# 2          | 1.4800     | 0.2960     | 7.6960
# 3          | 1.7104     | 0.3421     | 8.8941
# 4          | 1.8210     | 0.3642     | 9.4692
# 5          | 1.8741     | 0.3748     | 9.7452
# 6          | 1.8996     | 0.3799     | 9.8777
# 7          | 1.9118     | 0.3824     | 9.9413
# 8          | 1.9177     | 0.3835     | 9.9718
# 9          | 1.9205     | 0.3841     | 9.9865
# 10         | 1.9218     | 0.3844     | 9.9935
